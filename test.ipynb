# %%
import add_label as al
import to_binary as tb
import pandas as pd
import numpy as np

# %%
CBE_geneCounts = pd.read_csv('MayoRNAseq_RNAseq_CBE_geneCounts_normalized.tsv', sep='\t')
CBE_covariates = pd.read_csv('MayoRNAseq_RNAseq_CBE_covariates.csv')

# %%
CBE = al.add_label(CBE_geneCounts, CBE_covariates)

# %%
TCX_geneCounts = pd.read_csv('MayoRNAseq_RNAseq_TCX_geneCounts_normalized.tsv', sep='\t')
TCX_covariates = pd.read_csv('MayoRNAseq_RNAseq_TCX_covariates.csv')

# %%
TCX = al.add_label(TCX_geneCounts, TCX_covariates)

# %%
CBE_x, CBE_y = tb.to_binary(CBE)

# %%
CBEb = pd.concat([CBE_y, CBE_x], axis=1)

# %%
TCX_x, TCX_y = tb.to_binary(TCX)

# %%
TCXb = pd.concat([TCX_y, TCX_x], axis=1)

# %%
import linear_svc as ls

# %%
best_acc_CBE = ls.linear_svc(CBE_x, CBE_y)
# Out:
# selected num of features:  5
# C_best =  [21.48697412] highest accuracy =  [0.89375]
# selected num of features:  10
# C_best =  [200.] highest accuracy =  [0.88]
# selected num of features:  15
# C_best =  [7.04284115] highest accuracy =  [0.86875]
# selected num of features:  20
# C_best =  [5.32894271] highest accuracy =  [0.86875]
# selected num of features:  50
# C_best =  [12.30159931] highest accuracy =  [0.9]
# selected num of features:  75
# C_best =  [1.74668135] highest accuracy =  [0.9]
# selected num of features:  100
# C_best =  [2.30845028] highest accuracy =  [0.9125]
# selected num of features:  250
# C_best =  [1.         5.32894271] highest accuracy =  [0.9 0.9]
# selected num of features:  500
# C_best =  [49.60161148 65.55451795] highest accuracy =  [0.89375 0.89375]
# selected num of features:  1000
# C_best =  [ 4.03212706 65.55451795] highest accuracy =  [0.90625 0.90625]
# selected num of features:  5000
# C_best =  [9.30796486] highest accuracy =  [0.90625]
# selected num of features:  10000
# C_best =  [49.60161148 86.63820982] highest accuracy =  [0.86875 0.86875]
# [0.89375,
#  0.8800000000000001,
#  0.86875,
#  0.86875,
#  0.9,
#  0.9,
#  0.9125,
#  0.9,
#  0.89375,
#  0.90625,
#  0.90625,
#  0.86875]

# %%
best_acc_TCX = ls.linear_svc(TCX_x, TCX_y)
# Out:
# selected num of features:  5
# C_best =  [151.32934551] highest accuracy =  [0.8125]
# selected num of features:  10
# C_best =  [2.30845028 9.30796486] highest accuracy =  [0.79375 0.79375]
# selected num of features:  15
# C_best =  [1.74668135] highest accuracy =  [0.8875]
# selected num of features:  20
# C_best =  [16.25804865] highest accuracy =  [0.89375]
# selected num of features:  50
# C_best =  [65.55451795] highest accuracy =  [0.91875]
# selected num of features:  75
# C_best =  [ 1.74668135  9.30796486 49.60161148] highest accuracy =  [0.91875 0.91875 0.91875]
# selected num of features:  100
# C_best =  [28.3976304] highest accuracy =  [0.925]
# selected num of features:  250
# C_best =  [  9.30796486 200.        ] highest accuracy =  [0.90625 0.90625]
# selected num of features:  500
# C_best =  [16.25804865] highest accuracy =  [0.88125]
# selected num of features:  1000
# C_best =  [49.60161148] highest accuracy =  [0.88125]
# selected num of features:  5000
# C_best =  [151.32934551] highest accuracy =  [0.89375]
# selected num of features:  10000
# C_best =  [12.30159931 49.60161148] highest accuracy =  [0.89375 0.89375]

# %%
import acc_fea_plot as afp

# %%
afp.acc_fea_plot(best_acc_CBE)

# %%
afp.acc_fea_plot(best_acc_TCX)

# %%
import mlp as mlp
# Out:
# /Users/Abelard/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
mlp.mlp(100, CBE_x, CBE_y, 10)
# Out:
# number of gene 10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 40)                440
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 40)                0
# _________________________________________________________________
# activity_regularization_1 (A (None, 40)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 40)                1640
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 40)                0
# _________________________________________________________________
# activity_regularization_2 (A (None, 40)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 82
# =================================================================
# Total params: 2,162
# Trainable params: 2,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tsne_plot as tp

# %%
tp.tsne_plot(CBE_x, CBE_y, 2)
# Out:
# There are 2 unique target valuess in this dataset: [0 1]
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 159 samples in 0.004s...
# [t-SNE] Computed neighbors for 159 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 159 / 159
# [t-SNE] Mean sigma: 5104.356962
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 55.099049
# [t-SNE] Error after 1000 iterations: 0.246477

# %%
import pca_plot as pp

# %%
pp.pca_plot(CBE_x, CBE_y, 10)
# Out:
# There are 2 unique target valuess in this dataset: [0 1]
#
# Running PCA ...
# Explained variance: 0.9960
# Individual variance contributions:
# 0.9581089514054986
# 0.016315993732349526
# 0.006757390841156012
# 0.006028216587063822
# 0.0033910733865648926
# 0.0019359326684761904
# 0.0012869825965503689
# 0.0008639461489481775
# 0.0007722734021945475
# 0.000571431829052119

# %%
import AgeSex_plot as asp

# %%
asp.AgeSex_plot(CBE_covariates)

# %%
import amcon_select as aas

# %%
finC, finT = aas.amcon_select(CBEb, TCXb)

# %%
finC.shape
# Out:
# (132, 64254)

# %%
finT.shape
# Out:
# (132, 64254)

# %%
finC_y = finC['Diagnosis']
finC_y = pd.DataFrame(finC_y)
finC_y = finC_y.astype(int)
finC_x = finC.drop(['Diagnosis'], axis=1)

# %%
finT_y = finT['Diagnosis']
finT_y = pd.DataFrame(finT_y)
finT_y = finT_y.astype(int)
finT_x = finT.drop(['Diagnosis'], axis=1)

# %%
import linear_svc_cfin as lsc

# %%
com_acc = lsc.linear_svc_cfin(finC_x, finC_y, finT_x, finT_y)
# Out:
# C_best =  [9.30796486] highest accuracy =  [0.91593407]
# C_best =  [151.32934551 200.        ] highest accuracy =  [0.90824176 0.90824176]
# C_best =  [86.63820982] highest accuracy =  [0.91593407]
# C_best =  [3.05089575] highest accuracy =  [0.93901099]
# C_best =  [16.25804865] highest accuracy =  [0.92417582]
# C_best =  [  1.32162073   1.74668135   3.05089575   4.03212706   7.04284115
#   12.30159931  21.48697412  28.3976304   37.53089701  49.60161148
#  151.32934551 200.        ] highest accuracy =  [0.93131868 0.93131868 0.93131868 0.93131868 0.93131868 0.93131868
#  0.93131868 0.93131868 0.93131868 0.93131868 0.93131868 0.93131868]
# C_best =  [  1.           7.04284115  12.30159931  65.55451795 151.32934551
#  200.        ] highest accuracy =  [0.93846154 0.93846154 0.93846154 0.93846154 0.93846154 0.93846154]
# C_best =  [114.50285407] highest accuracy =  [0.92362637]
# C_best =  [16.25804865] highest accuracy =  [0.90164835]
# C_best =  [ 16.25804865 114.50285407] highest accuracy =  [0.93131868 0.93131868]
# C_best =  [200.] highest accuracy =  [0.87912088]
# C_best =  [65.55451795] highest accuracy =  [0.90054945]

# %%
import best_acc_plot as bap

# %%
bap.best_acc_plot(com_acc)

# %%
import linear_svc_ori as lso

# %%
ori_acc = lso.linear_svc_ori(finC_x, finC_y, finT_x, finT_y)
# Out:
# C_best =  [ 21.48697412 114.50285407] highest accuracy =  [0.90054945 0.90054945]
# C_best =  [86.63820982] highest accuracy =  [0.90054945]
# C_best =  [3.05089575] highest accuracy =  [0.90054945]
# C_best =  [ 1.          5.32894271 16.25804865] highest accuracy =  [0.89285714 0.89285714 0.89285714]
# C_best =  [9.30796486] highest accuracy =  [0.87802198]
# C_best =  [12.30159931] highest accuracy =  [0.87032967]
# C_best =  [1.74668135 2.30845028 5.32894271] highest accuracy =  [0.9010989 0.9010989 0.9010989]
# C_best =  [4.03212706] highest accuracy =  [0.93186813]
# C_best =  [1.] highest accuracy =  [0.93131868]
# C_best =  [37.53089701] highest accuracy =  [0.86318681]
# C_best =  [1.32162073] highest accuracy =  [0.85054945]
# C_best =  [1.] highest accuracy =  [0.82417582]

# %%
com_acc
# Out:
# [0.915934065934066,
#  0.9082417582417583,
#  0.915934065934066,
#  0.939010989010989,
#  0.9241758241758242,
#  0.9313186813186812,
#  0.9384615384615385,
#  0.9236263736263736,
#  0.9016483516483514,
#  0.9313186813186813,
#  0.8791208791208792,
#  0.9005494505494506]

# %%
sum(com_acc)/len(com_acc)
# Out:
# 0.917445054945055

# %%
ori_acc
# Out:
# [0.9005494505494506,
#  0.9005494505494507,
#  0.9005494505494506,
#  0.8928571428571429,
#  0.8780219780219779,
#  0.8703296703296705,
#  0.9010989010989011,
#  0.9318681318681318,
#  0.9313186813186812,
#  0.8631868131868131,
#  0.8505494505494505,
#  0.8241758241758241]

# %%
sum(ori_acc)/len(ori_acc)
# Out:
# 0.8870879120879122

# %%
bap.best_acc_plot(ori_acc)
